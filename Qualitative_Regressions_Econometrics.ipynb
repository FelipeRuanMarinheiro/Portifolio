# %% [markdown]
# <a href="https://colab.research.google.com/github/FelipeRuanMarinheiro/Portifolio/blob/main/Qualitative_Regressions_Econometrics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Modelos Qualitativos
# - Resposta qualitativa
# - MPL
# - Logit
# - Probit

# %% [markdown]
# ##LIBS

# %%
# !pip install matplotlib
# !pip install pandas

import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ##Exploratória

# %%
df = pd.read_csv('casa.csv', sep=';')

# %%
any_nulls = df.isnull().any().any()
print(f"valores nulos? {any_nulls}")
# Out:
# valores nulos? False

# %%
df.head()
# Out:
#    renda  casa
# 0   9000     0
# 1    998     0
# 2   4500     1
# 3   6000     1
# 4   2500     1

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import logit, probit, ols



# Regressão Linear (MPL)
X = sm.add_constant(df['renda'])
y = df['casa']
model_mpl = sm.OLS(y, X).fit()
print(model_mpl.summary())

# Regressão Logit
model_logit = logit('casa ~ renda', data=df).fit()
print(model_logit.summary())

# Regressão Probit
model_probit = probit('casa ~ renda', data=df).fit()
print(model_probit.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   casa   R-squared:                       0.120
# Model:                            OLS   Adj. R-squared:                  0.109
# Method:                 Least Squares   F-statistic:                     11.55
# Date:                Thu, 30 May 2024   Prob (F-statistic):            0.00103
# Time:                        22:49:45   Log-Likelihood:                -53.851
# No. Observations:                  87   AIC:                             111.7
# Df Residuals:                      85   BIC:                             116.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4747      0.070      6.820      0.000       0.336       0.613
# ...
